# %%
import pandas as pd
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('taxi_trial.csv')
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2015-12-01 00:00:00   2015-12-01 00:05:16                5
# 1         2  2015-12-01 00:00:00   2015-12-01 00:00:00                2
# 2         2  2015-12-01 00:00:00   2015-12-01 00:00:00                1
# 3         1  2015-12-01 00:00:01   2015-12-01 00:05:56                1
# 4         1  2015-12-01 00:00:01   2015-12-01 00:09:28                2
#
#    trip_distance  pickup_longitude  pickup_latitude  RatecodeID  \
# 0           0.96        -73.979942        40.765381           1
# 1           2.69        -73.972336        40.762379           1
# 2           2.62        -73.968849        40.764530           1
# 3           1.20        -73.993935        40.741684           1
# 4           3.00        -73.988922        40.726990           1
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# 0                  N         -73.966309         40.763088             1
# 1                  N         -73.993629         40.745998             1
# 2                  N         -73.974548         40.791641             1
# 3                  N         -73.997665         40.747467             1
# 4                  N         -73.975594         40.696869             2
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0          5.5    0.5      0.5        1.00           0.0
# 1         21.5    0.0      0.5        3.34           0.0
# 2         17.0    0.0      0.5        3.56           0.0
# 3          6.5    0.5      0.5        0.20           0.0
# 4         11.0    0.5      0.5        0.00           0.0
#
#    improvement_surcharge  total_amount
# 0                    0.3          7.80
# 1                    0.3         25.64
# 2                    0.3         21.36
# 3                    0.3          8.00
# 4                    0.3         12.30

# %% [markdown]
# 1. Pickup Longitude
# 2. Pickup Latitude
# 3. Dropoff Longitude
# 4. Dropoff Latitude

# %% [markdown]
# 1. Timediff- will dictate when loops occur
# 2. Trip distance-already kinda implicit
# 3. Payment-thickness of loops

# %%
df.drop(['VendorID','passenger_count','RatecodeID','store_and_fwd_flag','payment_type',
         'fare_amount','extra','mta_tax','tip_amount','tolls_amount','improvement_surcharge'],axis=1,inplace=True)
df.head()
# Out:
#   tpep_pickup_datetime tpep_dropoff_datetime  trip_distance  pickup_longitude  \
# 0  2015-12-01 00:00:00   2015-12-01 00:05:16           0.96        -73.979942
# 1  2015-12-01 00:00:00   2015-12-01 00:00:00           2.69        -73.972336
# 2  2015-12-01 00:00:00   2015-12-01 00:00:00           2.62        -73.968849
# 3  2015-12-01 00:00:01   2015-12-01 00:05:56           1.20        -73.993935
# 4  2015-12-01 00:00:01   2015-12-01 00:09:28           3.00        -73.988922
#
#    pickup_latitude  dropoff_longitude  dropoff_latitude  total_amount
# 0        40.765381         -73.966309         40.763088          7.80
# 1        40.762379         -73.993629         40.745998         25.64
# 2        40.764530         -73.974548         40.791641         21.36
# 3        40.741684         -73.997665         40.747467          8.00
# 4        40.726990         -73.975594         40.696869         12.30

# %%
def stringToDatetime(string):
    return datetime.datetime.strptime(string, '%Y-%m-%d %H:%M:%S')
def dateToNumber(date):
    return date.seconds
def toMinutes(time):
    return time/60

# %%
df['pickup']= df['tpep_pickup_datetime'].apply(stringToDatetime)
df['dropoff']= df['tpep_dropoff_datetime'].apply(stringToDatetime)
df.drop(['tpep_pickup_datetime','tpep_dropoff_datetime'],axis=1,inplace=True)
df['timediff']= df['dropoff']- df['pickup']
df['time']= df['timediff'].apply(dateToNumber)
df.drop(['pickup','dropoff','timediff'],axis=1,inplace=True)
df.head(10)
# Out:
#    trip_distance  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0           0.96        -73.979942        40.765381         -73.966309
# 1           2.69        -73.972336        40.762379         -73.993629
# 2           2.62        -73.968849        40.764530         -73.974548
# 3           1.20        -73.993935        40.741684         -73.997665
# 4           3.00        -73.988922        40.726990         -73.975594
# 5           6.30        -73.974083        40.762913         -74.012802
# 6           0.63        -73.968315        40.755329         -73.962082
# 7           1.91        -73.994209        40.746101         -74.004250
# 8           4.50        -74.006760        40.718906         -73.989693
# 9           1.42        -73.999634        40.734772         -73.989067
#
#    dropoff_latitude  total_amount  time
# 0         40.763088          7.80   316
# 1         40.745998         25.64     0
# 2         40.791641         21.36     0
# 3         40.747467          8.00   355
# 4         40.696869         12.30   567
# 5         40.702209         26.15   970
# 6         40.758915          6.36   167
# 7         40.721809         11.16   484
# 8         40.772854         21.36  1029
# 9         40.723122         12.25   639

# %%
df=df[df.dropoff_latitude>0]
df= df[df.total_amount>0]
df = df[(df.time>0) & (df.time<20000)]
df.head(20)
# Out:
#     trip_distance  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0            0.96        -73.979942        40.765381         -73.966309
# 3            1.20        -73.993935        40.741684         -73.997665
# 4            3.00        -73.988922        40.726990         -73.975594
# 5            6.30        -73.974083        40.762913         -74.012802
# 6            0.63        -73.968315        40.755329         -73.962082
# 7            1.91        -73.994209        40.746101         -74.004250
# 8            4.50        -74.006760        40.718906         -73.989693
# 9            1.42        -73.999634        40.734772         -73.989067
# 10           2.02        -73.982681        40.731312         -74.006012
# 12           1.00        -73.995766        40.743790         -74.002625
# 14           1.73        -73.999336        40.728321         -73.980881
# 15           1.77        -73.975899        40.755981         -73.977112
# 16           1.80        -73.988411        40.764423         -73.993782
# 17           2.90        -74.004623        40.721500         -73.977104
# 18          21.40        -73.781097        40.645000         -74.008568
# 19           4.80        -74.006035        40.735371         -73.970291
# 20           6.86        -73.984390        40.754848         -73.896873
# 22          19.00        -73.782219        40.644596         -73.984146
# 23           1.35        -73.987808        40.755196         -73.981781
# 24           0.83        -74.001228        40.751606         -73.992432
#
#     dropoff_latitude  total_amount  time
# 0          40.763088          7.80   316
# 3          40.747467          8.00   355
# 4          40.696869         12.30   567
# 5          40.702209         26.15   970
# 6          40.758915          6.36   167
# 7          40.721809         11.16   484
# 8          40.772854         21.36  1029
# 9          40.723122         12.25   639
# 10         40.745232         10.80   633
# 12         40.730545          9.45   346
# 14         40.737782         11.76   552
# 15         40.750175         16.64   907
# 16         40.743404         10.35   342
# 17         40.747017         15.38   624
# 18         40.702866         60.80  2622
# 19         40.690067         24.30  1187
# 20         40.751217         28.84  1105
# 22         40.769951         58.00  2607
# 23         40.768429          8.76   310
# 24         40.758259          5.80   133

# %%
sns.distplot(df.time)

# %%
sns.distplot(df.trip_distance)

# %%
sns.distplot(df.total_amount)

# %%
df.total_amount= df.total_amount.where(df.total_amount<75,75)
df.time= df.time.where(df.time<5280,5280)
df['time']= df['time'].apply(toMinutes)
df.head()
# Out:
#    trip_distance  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0           0.96        -73.979942        40.765381         -73.966309
# 3           1.20        -73.993935        40.741684         -73.997665
# 4           3.00        -73.988922        40.726990         -73.975594
# 5           6.30        -73.974083        40.762913         -74.012802
# 6           0.63        -73.968315        40.755329         -73.962082
#
#    dropoff_latitude  total_amount       time
# 0         40.763088          7.80   5.266667
# 3         40.747467          8.00   5.916667
# 4         40.696869         12.30   9.450000
# 5         40.702209         26.15  16.166667
# 6         40.758915          6.36   2.783333

# %%
df.to_csv('/home/benson/Dropbox/Code/Projects/P5_Projects/Mat259_Final/trial_data.csv',sep=',', index = False)

# %%
df['total_amount'].max()
# Out:
# 75.0
